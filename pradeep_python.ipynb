# %% [markdown]
# <a href="https://colab.research.google.com/github/wokwipradeep/matty/blob/main/pradeep_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud==1.8.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp310-cp310-linux_x86_64.whl size=402045 sha256=c7cc6dc415082de0bbcc0fdb65c1424d98a7c87c5615fb427c4ade72925e7353
#   Stored in directory: /root/.cache/pip/wheels/6b/b1/75/024072f28a2b9d6c4f80b35ebfd6ced7fd9fc58e9f1b933b9f
# Successfully built wordcloud
# ...
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.9.3
#     Uninstalling wordcloud-1.9.3:
#       Successfully uninstalled wordcloud-1.9.3
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
my_now=open('/content/abc.txt','r').read()
stopwords=set(STOPWORDS)
alice_wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
alice_wc.generate(my_now)
plt.imshow(alice_wc)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('/content/US_Unemployment_Oct2012.csv')
data2 = pd.read_csv('/content/Police_Department_Incidents_-_Previous_Year__2016_.csv')

# %%
data1.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
data2.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
import folium
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4, tiles='stamen toner', attr='Map data © OpenStreetMap contributors')
world_map

# %%
data2.shape
# Out:
# (14472, 13)

# %%
# prompt: getting coulmn thorugh slicing i

data2['PdDistrict'][0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d7761f9f7554> in <cell line: 3>()
#       1 # prompt: getting coulmn thorugh slicing i
#       2
# ----> 3 data2['PdDistrict'][0:5]
#
# NameError: name 'data2' is not defined

# %%
# Corrected code
data2.iloc[:,3]
# Out:
# 0          Friday
# 1          Friday
# 2          Monday
# 3         Tuesday
# 4          Friday
#            ...
# 14467      Friday
# 14468    Thursday
# 14469    Thursday
# 14470    Thursday
# 14471      Monday
# Name: DayOfWeek, Length: 14472, dtype: object

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.datasets import MNIST

# %%
dataset = MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 16743328.76it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 1170110.54it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 9826850.05it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 5108750.00it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
data = data2.iloc[0:100,:]

# %%
import folium
santran_map = folium.Map(location=[37.77, -122.42], zoom_start=12)
santran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Include = folium.map.FeatureGroup()
for lat, lng in zip(data.Y, data.X):
   Include.add_child(folium.features.Marker([lat, lng], popup='label', color='blue', fill=True, fill_color='white', fill_opacity=0.6))
santran_map.add_child(Include)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
stateˍunp = pd.read_json('/content/us-states.json')

# %%
import cv2
import numpy as np

# Read the image
image = cv2.imread('5.jpeg')

# Convert image to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define lower and upper bounds for the red color range
lower_red = np.array([0, 150, 96])
upper_red = np.array([14, 88, 130])

# Threshold the HSV image to get only red colors
mask = cv2.inRange(hsv, lower_red, upper_red)

# Find contours in the mask
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Loop over the contours
for contour in contours:
    # Calculate the area of each contour
    area = cv2.contourArea(contour)
    # If the area is small, ignore it (noise)
    if area > 100:
        # Draw the contour on the original image
        cv2.drawContours(image, [contour], -1, (0, 255, 0), 2)

# Display the result
# cv2.imshow('Red Ball Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Read the image
try:
    image = cv2.imread('1.jpg')
except FileNotFoundError:
    print("Error: Image file not found.")
except PermissionError:
    print("Error: Insufficient permissions to read image file.")

# Check if image is empty
if image is None:
    print("Error: Failed to read image.")
    exit()

# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (11, 11), 0)

# Detect circles using Hough Circle Transform
circles = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, dp=1, minDist=20, param1=50, param2=30, minRadius=10, maxRadius=50)

# If circles are found
if circles is not None:
    circles = np.round(circles[0, :]).astype("int")

    for (x, y, r) in circles:
        # Draw the circle
        cv2.circle(image, (x, y), r, (0, 255, 0), 4)

# Display the result
cv2.imshow('Circle Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Error: Failed to read image.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-55-44890767bfd9> in <cell line: 18>()
#      16
#      17 # Convert image to grayscale
# ---> 18 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      19
#      20 # Apply Gaussian blur to reduce noise
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
from google.colab.patches import cv2_imshow

# Display the result
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x757>
